# %%
import pandas as pd

# %%
df = pd.read_csv('../src/data/assessor.csv', parse_dates=['Current Sales Date'])
column_renames = {old: old.replace(' ', '') for old in df.columns}
df.rename(columns = column_renames, inplace=True)

df = df.query('ClosedRollYear == 2017')
# Out:
# /home/alex/EECS_731/EECS731_FinalProject/.venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.apply(lambda x: x.astype(str).str.lower() if x.dtype == 'O' else x)

# %%
df['SalesYear'] = df['CurrentSalesDate'].dt.year
df['SalesMonth'] = df['CurrentSalesDate'].dt.month
df['SalesDay'] = df['CurrentSalesDate'].dt.day

# %%
# Out:
#          ClosedRollYear                      PropertyLocation ParcelNumber  \
# 1199143          2017.0  0000 0200 hyde                st0000      0337021
# 1199144          2017.0  0000 v000 beideman            st0000      1100040
# 1199145          2017.0  0000 1096 point lobos         av0000      1313008
# 1199146          2017.0  0000 0321 polaris             wy0000      6498012
# 1615586          2017.0  0000 2655 hyde                st0w27    0026t206b
# ...                 ...                                   ...          ...
# 1823792          2017.0  0000 0215 sargent             st0000      7089047
# 1823793          2017.0  0000 5116cdiamond heights     bl0000     7515a049
# 1823794          2017.0  0000 0076 cameo               wy0000      7513047
# 1823795          2017.0  0000 8400 oceanview           te0402     7126a182
# 1823796          2017.0  0000 1790 eucalyptus          dr0000      7262012
#
#          Block   Lot  VolumeNumber UseCode              UseDefinition  \
# 1199143   0337   021             3    misc    miscellaneous/mixed-use
# 1199144   1100   040             8    misc    miscellaneous/mixed-use
# 1199145   1313   008            10    comr          commercial retail
# 1199146   6498   012            38    sres  single family residential
# 1615586  0026t  206b             1    comm            commercial misc
# ...        ...   ...           ...     ...                        ...
# 1823792   7089   047            42    sres  single family residential
# 1823793  7515a   049            44    sres  single family residential
# 1823794   7513   047            44    sres  single family residential
# 1823795  7126a   182            43    sres  single family residential
# 1823796   7262   012            44    sres  single family residential
#
#         PropertyClassCode PropertyClassCodeDefinition  ...  \
# 1199143                 x                        misc  ...
# 1199144                 x                        misc  ...
# 1199145                 c           commercial stores  ...
# 1199146                 d                    dwelling  ...
# 1615586                ts                   timeshare  ...
# ...                   ...                         ...  ...
# 1823792                 d                    dwelling  ...
# 1823793                 z                 condominium  ...
# 1823794                 d                    dwelling  ...
# 1823795                 z                 condominium  ...
# 1823796                 d                    dwelling  ...
#
#          AssessorNeighborhoodDistrict  AssessorNeighborhoodCode  \
# 1199143                           8.0                        8a
# 1199144                           6.0                        6d
# 1199145                           1.0                        1e
# 1199146                          10.0                       10b
# 1615586                           8.0                        8e
# ...                               ...                       ...
# 1823792                           3.0                        3g
# 1823793                           4.0                        4b
# 1823794                           4.0                        4b
# 1823795                           3.0                        3g
# 1823796                           3.0                        3a
#
#          AssessorNeighborhood  SupervisorDistrict        AnalysisNeighborhood  \
# 1199143              downtown                   6                  tenderloin
# 1199144      western addition                   5            western addition
# 1199145        outer richmond                   1              outer richmond
# 1199146         croker amazon                  11                   excelsior
# 1615586          russian hill                   2                russian hill
# ...                       ...                 ...                         ...
# 1823792     ingleside heights                  11  oceanview/merced/ingleside
# 1823793       diamond heights                   8                  noe valley
# 1823794       diamond heights                   8                  noe valley
# 1823795     ingleside heights                   7  oceanview/merced/ingleside
# 1823796            lake shore                   7             sunset/parkside
#
#                                           the_geom          RowID SalesYear  \
# 1199143   point (-122.415461030521 37.78283692859)    20170337021       NaN
# 1199144  point (-122.438147311756 37.782276382096)    20171100040       NaN
# 1199145  point (-122.514263887916 37.778004375245)    20171313008       NaN
# 1199146   point (-122.43921944249 37.708275212573)    20176498012       NaN
# 1615586  point (-122.420596543189 37.805473429601)  20170026t206b       NaN
# ...                                            ...            ...       ...
# 1823792  point (-122.464739571357 37.715912783657)    20177089047       NaN
# 1823793  point (-122.441556424074 37.746821733478)   20177515a049    1987.0
# 1823794   point (-122.443491596582 37.74459693514)    20177513047    2003.0
# 1823795  point (-122.467667844218 37.710481672448)   20177126a182    2015.0
# 1823796  point (-122.491096874305 37.730863694252)    20177262012    2011.0
#
#          SalesMonth  SalesDay
# 1199143         NaN       NaN
# 1199144         NaN       NaN
# 1199145         NaN       NaN
# 1199146         NaN       NaN
# 1615586         NaN       NaN
# ...             ...       ...
# 1823792         NaN       NaN
# 1823793         6.0      25.0
# 1823794        10.0       3.0
# 1823795         8.0      25.0
# 1823796         6.0       1.0
#
# [207848 rows x 46 columns]
