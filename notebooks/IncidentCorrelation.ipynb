# %%
import pandas as pd 
import numpy as np

# %%
df_dp = pd.read_csv('../data/processed/damagedProperty.csv')
df_fire = pd.read_csv('../data/processed/fireIncidents.csv')
df_homeless = pd.read_csv('../data/processed/homelessConcerns.csv')
df_illegal = pd.read_csv('../data/processed/illegalPostings.csv')
df_noise=pd.read_csv('../data/processed/noiseReports.csv')
df_eviction = pd.read_csv('../data/processed/Eviction.csv')
df_incidents = pd.read_csv('../data/processed/incidents.csv')
df_graffiti = pd.read_csv('../data/processed/graffiti.csv')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (12,13,14,15,18,19,20,45,46,55,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_dp.head(10)
# Out:
#    Unnamed: 0    CaseID               Opened               Closed  \
# 0           0  11771122  2019-12-04 16:24:00                  NaN
# 1           1  11770741  2019-12-04 15:14:00                  NaN
# 2           2  11768297  2019-12-04 09:06:00                  NaN
# 3           3  11769772  2019-12-04 12:47:00  2019-12-04 13:30:01
# 4           4  11770411  2019-12-04 14:23:00                  NaN
# 5           5  11768661  2019-12-04 09:57:00                  NaN
# 6           6  11770081  2019-12-04 13:34:00                  NaN
# 7           7  11767642  2019-12-04 07:08:00  2019-12-04 07:33:00
# 8           8  11770031  2019-12-04 13:27:00                  NaN
# 9           9  11769880  2019-12-04 13:04:00                  NaN
#
#                Updated  Status  \
# 0  2019-12-04 17:00:02    Open
# 1  2019-12-04 17:06:56    Open
# 2  2019-12-04 09:45:02    Open
# 3  2019-12-04 13:30:01  Closed
# 4  2019-12-04 15:00:01    Open
# 5  2019-12-04 10:15:02    Open
# 6  2019-12-04 14:00:02    Open
# 7  2019-12-04 07:33:00  Closed
# 8  2019-12-04 20:57:39    Open
# 9  2019-12-04 13:45:02    Open
#
#                                         Status Notes  \
# 0                                           accepted
# 1                                               Open
# 2                                           accepted
# 3                 meter shop has closed this request
# 4                                           accepted
# 5                                           accepted
# 6                                           accepted
# 7  Multiple intersection along the Great Highway ...
# 8                                               Open
# 9                                           accepted
#
#                  Responsible Agency          Category            Request Type  \
# 0              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 1          DPT - Traffic Signal - G  Damaged Property  Damaged Traffic_Signal
# 2              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 3              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 4              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 5              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 6              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
# 7         311 Service Request Queue  Damaged Property  Damaged Traffic_Signal
# 8  311 Service Request Queue - Hold  Damaged Property           Damaged other
# 9              DPT Meter_Bike Queue  Damaged Property   Damaged Parking_Meter
#
#   ...                  Neighborhood Police District          Y           X  \
# 0 ...                haight ashbury            park  37.770008 -122.446930
# 1 ...            financial district         central  37.793781 -122.402954
# 2 ...  laurel heights / jordan park        richmond  37.786232 -122.453682
# 3 ...                    polk gulch        northern  37.790577 -122.420685
# 4 ...                    tenderloin        northern  37.784645 -122.420021
# 5 ...                       mission         mission  37.761749 -122.420815
# 6 ...                inner richmond        richmond  37.783329 -122.466438
# 7 ...                  outer sunset         taraval  37.749111 -122.507942
# 8 ...                       bayview         bayview  37.737200 -122.394691
# 9 ...                     chinatown         central  37.790718 -122.405197
#
#                           Point          Source  \
# 0  (37.77000809, -122.44692993)           Phone
# 1   (37.79378128, -122.4029541)           Phone
# 2  (37.78623199, -122.45368195)           Phone
# 3  (37.79057693, -122.42068481)           Phone
# 4  (37.78464508, -122.42002106)           Phone
# 5  (37.76174927, -122.42081451)           Phone
# 6  (37.78332901, -122.46643829)           Phone
# 7   (37.74911118, -122.5079422)           Phone
# 8  (37.73719992, -122.39469085)  Mobile/Open311
# 9  (37.79071808, -122.40519714)           Phone
#
#                                            Media URL  Year Month Day
# 0                                                NaN  2019    12   4
# 1                                                NaN  2019    12   4
# 2                                                NaN  2019    12   4
# 3                                                NaN  2019    12   4
# 4                                                NaN  2019    12   4
# 5                                                NaN  2019    12   4
# 6                                                NaN  2019    12   4
# 7                                                NaN  2019    12   4
# 8  http://mobile311.sfgov.org/reports/11770031/ph...  2019    12   4
# 9                                                NaN  2019    12   4
#
# [10 rows x 24 columns]

# %%
df_graffiti=df_graffiti.rename(columns={"Supervisor District": "SupervisorDistrict"})
graffiti_districts = df_graffiti.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_dp=df_dp.rename(columns={"Supervisor District": "SupervisorDistrict"})
dp_districts = df_dp.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_fire=df_fire.rename(columns={"Supervisor District": "SupervisorDistrict"})
fire_districts = df_fire.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_homeless=df_homeless.rename(columns={"Supervisor District": "SupervisorDistrict"})
homeless_districts = df_homeless.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_noise=df_noise.rename(columns={"Supervisor District": "SupervisorDistrict"})
noise_districts = df_noise.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_eviction=df_eviction.rename(columns={"Supervisor District": "SupervisorDistrict"})
eviction_districts = df_eviction.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

df_illegal=df_illegal.rename(columns={"Supervisor District": "SupervisorDistrict"})
illegal_districts = df_illegal.groupby(['SupervisorDistrict']).SupervisorDistrict.count()

# %%
goods=["illegal_districts", "eviction_districts", "noise_districts", "homeless_districts", "fire_districts", "dp_districts", "graffiti_districts"]
goods
# Out:
# ['illegal_districts',
#  'eviction_districts',
#  'noise_districts',
#  'homeless_districts',
#  'fire_districts',
#  'dp_districts',
#  'graffiti_districts']

# %%
def getPercent(list1):
    evList=[]
    listsum=0
    for x in list1:
        listsum=listsum+x
    for x in list1:
        evList.append(x/listsum)
    return(evList)

# %%
illegalPerc=getPercent(illegal_districts)
graffitiPerc=getPercent(graffiti_districts)
firePerc=getPercent(fire_districts)
noisePerc=getPercent(noise_districts)
homelessPerc=getPercent(homeless_districts)
evictionPerc=getPercent(eviction_districts)
dpPerc=getPercent(dp_districts)

# %%
temp=df_graffiti.groupby(['SupervisorDistrict'], as_index=False).CaseID.count()
supervisorDistrict=list(temp['SupervisorDistrict'])

# %%
dict = {'IllegalCases': illegalPerc, 'GraffitiCases': graffitiPerc, 'FireCases': firePerc, 'NoiseCases': noisePerc, 'HomelessCases': homelessPerc,
       'EvictionCases': evictionPerc, 'DamagedPropertyCases': dpPerc}   
df_perc = pd.DataFrame(dict) 
df_perc
# Out:
#     IllegalCases  GraffitiCases  FireCases  NoiseCases  HomelessCases  \
# 0       0.144927       0.083353   0.043596    0.046675       0.055123
# 1       0.101368       0.042507   0.087469    0.067863       0.033911
# 2       0.047230       0.108512   0.155362    0.133181       0.131665
# 3       0.046425       0.038550   0.027386    0.036059       0.006056
# 4       0.278787       0.178613   0.107940    0.112827       0.086162
# 5       0.056083       0.118093   0.243817    0.238989       0.306239
# 6       0.053903       0.030323   0.052890    0.023118       0.004360
# 7       0.133459       0.109809   0.074796    0.104360       0.123257
# 8       0.080729       0.188906   0.084350    0.121162       0.145611
# 9       0.039065       0.052413   0.085798    0.076461       0.103325
# 10      0.018024       0.048922   0.036595    0.039305       0.004291
#
#     EvictionCases  DamagedPropertyCases
# 0        0.083655              0.054660
# 1        0.083198              0.062524
# 2        0.094328              0.243698
# 3        0.064749              0.031087
# 4        0.115471              0.108593
# 5        0.106119              0.266260
# 6        0.085027              0.036428
# 7        0.130896              0.056730
# 8        0.114912              0.081371
# 9        0.060048              0.036947
# 10       0.061598              0.021702

# %%
df = pd.DataFrame({'IllegalCases': illegalPerc, 'GraffitiCases': graffitiPerc, 'FireCases': firePerc, 'NoiseCases': noisePerc, 'HomelessCases': homelessPerc,
       'EvictionCases': evictionPerc, 'DamagedPropertyCases': dpPerc}, index=supervisorDistrict)
df
# Out:
#       IllegalCases  GraffitiCases  FireCases  NoiseCases  HomelessCases  \
# 1.0       0.144927       0.083353   0.043596    0.046675       0.055123
# 2.0       0.101368       0.042507   0.087469    0.067863       0.033911
# 3.0       0.047230       0.108512   0.155362    0.133181       0.131665
# 4.0       0.046425       0.038550   0.027386    0.036059       0.006056
# 5.0       0.278787       0.178613   0.107940    0.112827       0.086162
# 6.0       0.056083       0.118093   0.243817    0.238989       0.306239
# 7.0       0.053903       0.030323   0.052890    0.023118       0.004360
# 8.0       0.133459       0.109809   0.074796    0.104360       0.123257
# 9.0       0.080729       0.188906   0.084350    0.121162       0.145611
# 10.0      0.039065       0.052413   0.085798    0.076461       0.103325
# 11.0      0.018024       0.048922   0.036595    0.039305       0.004291
#
#       EvictionCases  DamagedPropertyCases
# 1.0        0.083655              0.054660
# 2.0        0.083198              0.062524
# 3.0        0.094328              0.243698
# 4.0        0.064749              0.031087
# 5.0        0.115471              0.108593
# 6.0        0.106119              0.266260
# 7.0        0.085027              0.036428
# 8.0        0.130896              0.056730
# 9.0        0.114912              0.081371
# 10.0       0.060048              0.036947
# 11.0       0.061598              0.021702

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df.index.name = 'name'

for name,row in df.iterrows():
  plt.scatter(row['GraffitiCases'],row['HomelessCases'], label=name)

plt.xlabel('Graffiti')
plt.ylabel('Homeless')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
X = df['GraffitiCases'].values.reshape(-1,1)
y = df['HomelessCases'].values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[0.21363166],
#        [0.04444181],
#        [0.11965132]])

# %%
y_pred = [y for x in y_pred for y in x]
y_test = [y for x in y_test for y in x]
X_test = [y for x in X_test for y in x]
X_train = [y for x in X_train for y in x]
y_train = [y for x in y_train for y in x]

# %%
dict = {'Actual': y_test, 'Predicted': y_pred}   
df_pred = pd.DataFrame(dict) 
df_pred
# Out:
#      Actual  Predicted
# 0  0.086162   0.213632
# 1  0.103325   0.044442
# 2  0.131665   0.119651

# %%
for name,row in df.iterrows():
  plt.scatter(row['GraffitiCases'],row['HomelessCases'], label=name)

plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Graffiti')
plt.ylabel('Homeless')
plt.legend()
plt.show()

# %%
colList=list(df.columns)
colList
# Out:
# ['IllegalCases',
#  'GraffitiCases',
#  'FireCases',
#  'NoiseCases',
#  'HomelessCases',
#  'EvictionCases',
#  'DamagedPropertyCases']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
fig, ax = plt.subplots(figsize=(10,10))
cl = df[['IllegalCases',
 'GraffitiCases',
  'NoiseCases',
 'HomelessCases',
 'EvictionCases',
 'DamagedPropertyCases']].corr()
graph=sns.heatmap(cl, square = True, ax=ax)
plt.savefig('heatMap.png', bbox_inches='tight', dpi=300)
#graph.figure.savefig( "../../figures/factorHeatMap", dpi=300, format="png", bbox_inches='tight')

# %%
illegal_districts
# Out:
# SupervisorDistrict
# 1.0      8644
# 2.0      6046
# 3.0      2817
# 4.0      2769
# 5.0     16628
# 6.0      3345
# 7.0      3215
# 8.0      7960
# 9.0      4815
# 10.0     2330
# 11.0     1075
# Name: SupervisorDistrict, dtype: int64

# %%
df_perc
# Out:
#     IllegalCases  GraffitiCases  FireCases  NoiseCases  HomelessCases  \
# 0       0.144927       0.083353   0.043596    0.046675       0.055123
# 1       0.101368       0.042507   0.087469    0.067863       0.033911
# 2       0.047230       0.108512   0.155362    0.133181       0.131665
# 3       0.046425       0.038550   0.027386    0.036059       0.006056
# 4       0.278787       0.178613   0.107940    0.112827       0.086162
# 5       0.056083       0.118093   0.243817    0.238989       0.306239
# 6       0.053903       0.030323   0.052890    0.023118       0.004360
# 7       0.133459       0.109809   0.074796    0.104360       0.123257
# 8       0.080729       0.188906   0.084350    0.121162       0.145611
# 9       0.039065       0.052413   0.085798    0.076461       0.103325
# 10      0.018024       0.048922   0.036595    0.039305       0.004291
#
#     EvictionCases  DamagedPropertyCases
# 0        0.083655              0.054660
# 1        0.083198              0.062524
# 2        0.094328              0.243698
# 3        0.064749              0.031087
# 4        0.115471              0.108593
# 5        0.106119              0.266260
# 6        0.085027              0.036428
# 7        0.130896              0.056730
# 8        0.114912              0.081371
# 9        0.060048              0.036947
# 10       0.061598              0.021702

# %%
df_perc.to_csv('Cases.csv', index = None, header=True)

# %%
df_perc.insert(0, "SupervisorDistict", supervisorDistrict)

# %%
df_perc.head(10)
# Out:
#    SupervisorDistict  IllegalCases  GraffitiCases  FireCases  NoiseCases  \
# 0                1.0      0.144927       0.083353   0.043596    0.046675
# 1                2.0      0.101368       0.042507   0.087469    0.067863
# 2                3.0      0.047230       0.108512   0.155362    0.133181
# 3                4.0      0.046425       0.038550   0.027386    0.036059
# 4                5.0      0.278787       0.178613   0.107940    0.112827
# 5                6.0      0.056083       0.118093   0.243817    0.238989
# 6                7.0      0.053903       0.030323   0.052890    0.023118
# 7                8.0      0.133459       0.109809   0.074796    0.104360
# 8                9.0      0.080729       0.188906   0.084350    0.121162
# 9               10.0      0.039065       0.052413   0.085798    0.076461
#
#    HomelessCases  EvictionCases  DamagedPropertyCases
# 0       0.055123       0.083655              0.054660
# 1       0.033911       0.083198              0.062524
# 2       0.131665       0.094328              0.243698
# 3       0.006056       0.064749              0.031087
# 4       0.086162       0.115471              0.108593
# 5       0.306239       0.106119              0.266260
# 6       0.004360       0.085027              0.036428
# 7       0.123257       0.130896              0.056730
# 8       0.145611       0.114912              0.081371
# 9       0.103325       0.060048              0.036947
