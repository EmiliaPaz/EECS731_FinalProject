# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../data/Neighborhood_Zhvi_AllHomes.csv')
df
# Out:
#       RegionID                                         RegionName  \
# 0       274772                                   Northeast Dallas
# 1       192689                                           Paradise
# 2       270958                                    Upper West Side
# 3       118208                                  South Los Angeles
# 4       270957                                    Upper East Side
# 5       192820                                      Sunrise Manor
# 6       192796                                      Spring Valley
# 7       268496                              Southeast Los Angeles
# 8       194430                                      East New York
# 9       112547                                    Paradise Valley
# 10      198687                                 Washington Heights
# 11      111818                                        Deer Valley
# 12      267955                                     North Mountain
# ...

# %%
df=df[df.City == 'San Francisco']
df
# Out:
#       RegionID             RegionName           City State  \
# 164     268384           Outer Sunset  San Francisco    CA
# 230     274552                Mission  San Francisco    CA
# 350     268383         Outer Richmond  San Francisco    CA
# 422     268219         Inner Richmond  San Francisco    CA
# 473     268396               Parkside  San Francisco    CA
# 497     268491        South of Market  San Francisco    CA
# 540     268150              Excelsior  San Francisco    CA
# 548     268385        Pacific Heights  San Francisco    CA
# 724     268020         Bernal Heights  San Francisco    CA
# 830     268337               Nob Hill  San Francisco    CA
# 852     117447                Portola  San Francisco    CA
# 855     118904       Western Addition  San Francisco    CA
# 874     272885                Bayview  San Francisco    CA
# 881     268414           Potrero Hill  San Francisco    CA
# 889     268338             Noe Valley  San Francisco    CA
# ...

# %%
df.isnull().sum()
# Out:
# RegionID      0
# RegionName    0
# City          0
# State         0
# Metro         0
# CountyName    0
# SizeRank      0
# 1996-04       2
# 1996-05       2
# 1996-06       2
# 1996-07       2
# 1996-08       2
# 1996-09       2
# 1996-10       2
# 1996-11       2
# 1996-12       2
# 1997-01       2
# 1997-02       2
# 1997-03       2
# 1997-04       2
# 1997-05       2
# 1997-06       2
# 1997-07       2
# 1997-08       2
# 1997-09       2
# 1997-10       2
# 1997-11       2
# 1997-12       2
# 1998-01       2
# 1998-02       2
#              ..
# 2017-05       0
# 2017-06       0
# 2017-07       0
# 2017-08       0
# 2017-09       0
# 2017-10       0
# 2017-11       0
# 2017-12       0
# 2018-01       0
# 2018-02       0
# 2018-03       0
# 2018-04       0
# 2018-05       0
# 2018-06       0
# 2018-07       0
# 2018-08       0
# 2018-09       0
# 2018-10       0
# 2018-11       0
# 2018-12       0
# 2019-01       0
# 2019-02       0
# 2019-03       0
# 2019-04       0
# ...

# %%
df.dropna(inplace=True)
df
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       RegionID             RegionName           City State  \
# 164     268384           Outer Sunset  San Francisco    CA
# 230     274552                Mission  San Francisco    CA
# 350     268383         Outer Richmond  San Francisco    CA
# 422     268219         Inner Richmond  San Francisco    CA
# 473     268396               Parkside  San Francisco    CA
# 497     268491        South of Market  San Francisco    CA
# 540     268150              Excelsior  San Francisco    CA
# 548     268385        Pacific Heights  San Francisco    CA
# 724     268020         Bernal Heights  San Francisco    CA
# ...

# %%
df.isnull().sum()
# Out:
# RegionID      0
# RegionName    0
# City          0
# State         0
# Metro         0
# CountyName    0
# SizeRank      0
# 1996-04       0
# 1996-05       0
# 1996-06       0
# 1996-07       0
# 1996-08       0
# 1996-09       0
# 1996-10       0
# 1996-11       0
# 1996-12       0
# 1997-01       0
# 1997-02       0
# 1997-03       0
# 1997-04       0
# 1997-05       0
# 1997-06       0
# 1997-07       0
# 1997-08       0
# 1997-09       0
# 1997-10       0
# 1997-11       0
# 1997-12       0
# 1998-01       0
# 1998-02       0
#              ..
# 2017-05       0
# 2017-06       0
# 2017-07       0
# 2017-08       0
# 2017-09       0
# 2017-10       0
# 2017-11       0
# 2017-12       0
# 2018-01       0
# 2018-02       0
# 2018-03       0
# 2018-04       0
# 2018-05       0
# 2018-06       0
# 2018-07       0
# 2018-08       0
# 2018-09       0
# 2018-10       0
# 2018-11       0
# 2018-12       0
# 2019-01       0
# 2019-02       0
# 2019-03       0
# 2019-04       0
# ...

# %%
df.groupby(df['RegionName']).count()
# Out:
#                        RegionID  City  State  Metro  CountyName  SizeRank  \
# RegionName
# Bayview                       1     1      1      1           1         1
# Bernal Heights                1     1      1      1           1         1
# Buena Vista                   1     1      1      1           1         1
# Corona Heights                1     1      1      1           1         1
# Cow Hollow                    1     1      1      1           1         1
# Crocker Amazon                1     1      1      1           1         1
# Diamond Heights               1     1      1      1           1         1
# Downtown                      1     1      1      1           1         1
# Excelsior                     1     1      1      1           1         1
# Forest Hill                   1     1      1      1           1         1
# Forest Knolls                 1     1      1      1           1         1
# ...

# %%
colList=list(df.columns)
list1=[]
for x in range(148, len(colList)):
    list1.append(colList[x])
list1
# Out:
# ['2008-01',
#  '2008-02',
#  '2008-03',
#  '2008-04',
#  '2008-05',
#  '2008-06',
#  '2008-07',
#  '2008-08',
#  '2008-09',
#  '2008-10',
#  '2008-11',
#  '2008-12',
#  '2009-01',
#  '2009-02',
#  '2009-03',
#  '2009-04',
#  '2009-05',
#  '2009-06',
#  '2009-07',
#  '2009-08',
#  '2009-09',
#  '2009-10',
#  '2009-11',
#  '2009-12',
#  '2010-01',
#  '2010-02',
#  '2010-03',
#  '2010-04',
#  '2010-05',
#  '2010-06',
#  '2010-07',
#  '2010-08',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
# ...

# %%
df3 = df.loc[:, list1]
df3
# Out:
#         2008-01    2008-02    2008-03    2008-04    2008-05    2008-06  \
# 164    732900.0   728800.0   725600.0   723100.0   720600.0   717500.0
# 230    785800.0   785400.0   783900.0   781400.0   778900.0   776500.0
# 350    845200.0   839100.0   831900.0   823500.0   813800.0   803200.0
# 422   1074700.0  1069600.0  1064300.0  1058500.0  1051500.0  1044300.0
# 473    807600.0   804000.0   799800.0   794700.0   788500.0   781800.0
# 497    672600.0   668300.0   663100.0   657300.0   651700.0   646800.0
# 540    678800.0   669800.0   661100.0   651800.0   641900.0   632400.0
# 548   1381100.0  1378900.0  1375600.0  1374800.0  1371900.0  1361900.0
# 724    806700.0   802700.0   798900.0   795400.0   791600.0   786500.0
# 830    986300.0   987200.0   984100.0   977500.0   969900.0   963400.0
# 852    688000.0   681700.0   676400.0   671500.0   667100.0   662700.0
# 855    733800.0   722800.0   714400.0   707800.0   702500.0   699000.0
# ...

# %%
df['mean'] = df3.mean(axis=1)
df.head(10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      RegionID       RegionName           City State  \
# 164    268384     Outer Sunset  San Francisco    CA
# 230    274552          Mission  San Francisco    CA
# 350    268383   Outer Richmond  San Francisco    CA
# 422    268219   Inner Richmond  San Francisco    CA
# 473    268396         Parkside  San Francisco    CA
# 497    268491  South of Market  San Francisco    CA
# 540    268150        Excelsior  San Francisco    CA
# 548    268385  Pacific Heights  San Francisco    CA
# 724    268020   Bernal Heights  San Francisco    CA
# ...

# %%
colList=list(df.columns)
colList
# Out:
# ['RegionID',
#  'RegionName',
#  'City',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
# ...

# %%
df2 = df.loc[:, ['RegionName','mean']]

# %%
df2
# Out:
#                  RegionName          mean
# 164            Outer Sunset  8.714352e+05
# 230                 Mission  1.032278e+06
# 350          Outer Richmond  9.992535e+05
# 422          Inner Richmond  1.406422e+06
# 473                Parkside  9.581704e+05
# 497         South of Market  7.602437e+05
# 540               Excelsior  7.156366e+05
# 548         Pacific Heights  1.620902e+06
# 724          Bernal Heights  1.045777e+06
# 830                Nob Hill  1.182511e+06
# 852                 Portola  7.524035e+05
# 855        Western Addition  8.654570e+05
# 874                 Bayview  5.842704e+05
# 881            Potrero Hill  1.046387e+06
# 889              Noe Valley  1.456558e+06
# 945            Inner Sunset  1.173103e+06
# 972       Visitacion Valley  6.200458e+05
# 973          Crocker Amazon  7.150810e+05
# 1070    Golden Gate Heights  1.251895e+06
# 1112                 Marina  1.793954e+06
# 1130              Ingleside  7.190972e+05
# ...

# %%
df2.to_csv('NeighborhoodValue2.csv', index = None, header=True)

# %%
list1.append("RegionName")
list1.append("mean")

# %%
df3 = df.loc[:, list1]

# %%
df3.to_csv('NeighborhoodValue3.csv', index = None, header=True)
